# %% [markdown]
# # Свёрточные нейронные сети. Часть 2.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

import tensorflow as tf

# %% [markdown]
# ## Загрузка и подготовка датасета

# %%
(train_x, train_y), (test_x, test_y) = tf.keras.datasets.cifar10.load_data()

# %%
_CIFAR_SIZE = 32

train_x = train_x.reshape(-1, _CIFAR_SIZE, _CIFAR_SIZE, 3).astype(np.float32) / 255.
test_x = test_x.reshape(-1, _CIFAR_SIZE, _CIFAR_SIZE, 3).astype(np.float32) / 255.

train_y = train_y.astype(np.int32).reshape((-1,))
test_y = test_y.astype(np.int32).reshape((-1,))

print(train_x.shape, train_x.dtype)
print(test_x.shape, test_x.dtype)
print(train_y.shape, train_y.dtype)
print(test_y.shape, test_y.dtype)
# Out:
# (50000, 32, 32, 3) float32
# (10000, 32, 32, 3) float32
# (50000,) int32
# (10000,) int32

# %% [markdown]
# ## Визуализация датасета

# %%
some_samples = train_x[:32, ...]
some_labelss = train_y[:32, ...]

fig = plt.figure(figsize=(10, 6))
for j in range(some_samples.shape[0]):
    ax = fig.add_subplot(4, 8, j+1)
    ax.imshow(some_samples[j,:,:,:])
    plt.xticks([]), plt.yticks([])
    plt.title(f'label: {some_labelss[j]}')
plt.show()

# %% [markdown]
# ## Создание пайплайна данных

# %%
NUM_EPOCHS = 4
BATCH_SIZE = 64

train_ds = tf.data.Dataset.from_tensor_slices((train_x, train_y))
train_ds = train_ds.shuffle(buffer_size=train_x.shape[0])
train_ds = train_ds.repeat(NUM_EPOCHS)
train_ds = train_ds.batch(BATCH_SIZE)

# %% [markdown]
# ## Создание модели CNN

# %%
class Model(tf.keras.Model):
    
    def __init__(self):
        super(Model, self).__init__()
        
        self.conv1 = tf.keras.layers.Conv2D(32, (5, 5), activation='relu', padding='same')
        self.conv2 = tf.keras.layers.Conv2D(64, (5, 5), activation='relu', padding='same')
        self.fc1 = tf.keras.layers.Dense(256, activation='relu')
        self.fc2 = tf.keras.layers.Dense(10, activation=None)
        self.max_pool = tf.keras.layers.MaxPooling2D((2, 2), (2, 2))
        self.flatten = tf.keras.layers.Flatten()
        
    def call(self, inp):

        out = self.conv1(inp)
        out = self.max_pool(out)
        out = self.conv2(out)
        out = self.max_pool(out)
        out = self.flatten(out)
        out = self.fc1(out)
        out = self.fc2(out)
        
        return out
    
model = Model()

# %% [markdown]
# ## Функция потерь и функция вычисления точности

# %%
def loss(logits, labels):
    return tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(
        logits=logits, labels=labels))

def accuracy(logits, labels):
    predictions = tf.argmax(logits, axis=1, output_type=tf.int32)
    return tf.reduce_mean(tf.cast(tf.equal(predictions, labels), dtype=tf.float32))

# %% [markdown]
# ## Подготовка к обучению

# %%
LEARNING_RATE = 0.001

# optimizer = tf.keras.optimizers.SGD(LEARNING_RATE)
optimizer = tf.keras.optimizers.Adam(LEARNING_RATE)

# writer = tf.summary.create_file_writer('logs/sgd')
writer = tf.summary.create_file_writer('logs/adam')

# %% [markdown]
# ## Цикл обучения модели

# %%
# %%time

for iteration, (images, labels) in enumerate(train_ds):

    # Forward
    with tf.GradientTape() as tape:
        logits = model(images)
        
        loss_value = loss(logits, labels)
        
    # Backward
    grads = tape.gradient(loss_value, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    
    # Calc and display loss/accuracy
    if iteration % 200 == 0:
        test_logits = model(test_x[:256, ...])
        accuracy_value = accuracy(test_logits, test_y[:256, ...])
        
        print("[%4d] Accuracy: %5.2f %%" % (
            iteration, accuracy_value.numpy()*100))
        
        with writer.as_default():
            tf.summary.scalar('accuracy', accuracy_value, iteration)
            tf.summary.scalar('loss', loss_value, iteration)
# Out:
# [   0] Accuracy:  9.38 %
# [ 200] Accuracy: 46.48 %
# [ 400] Accuracy: 55.08 %
# [ 600] Accuracy: 52.73 %
# [ 800] Accuracy: 58.20 %
# [1000] Accuracy: 57.03 %
# [1200] Accuracy: 61.72 %
# [1400] Accuracy: 65.23 %
# [1600] Accuracy: 66.02 %
# [1800] Accuracy: 61.72 %
# [2000] Accuracy: 65.62 %
# [2200] Accuracy: 69.14 %
# [2400] Accuracy: 67.19 %
# [2600] Accuracy: 68.36 %
# [2800] Accuracy: 69.14 %
# [3000] Accuracy: 66.80 %
# CPU times: user 22.6 s, sys: 405 ms, total: 23 s
# Wall time: 22.8 s

# %% [markdown]
# ## Оценка качества модели

# %%
# %%time

test_logits = model(test_x)
accuracy_value = accuracy(test_logits, test_y).numpy()
print("Final Accuracy: %5.2f %%" % (accuracy_value * 100))
# Out:
# Final Accuracy: 69.32 %
# CPU times: user 180 ms, sys: 63.6 ms, total: 243 ms
# Wall time: 245 ms

# %% [markdown]
# ## TensorBoard

# %% [markdown]
# ## Функция для инференса и отображения результата предсказания

# %%
def test_item(sample):
    
    logits = model(sample[None, ...])[0]
    prediction = tf.nn.softmax(logits)
    ans = np.argmax(prediction)
    
    fig = plt.figure(figsize=(12,4))

    ax = fig.add_subplot(1, 2, 1)
    ax.imshow(sample[:,:,0], cmap='gray')
    plt.xticks([]), plt.yticks([])

    ax = fig.add_subplot(1, 2, 2)
    bar_list = ax.bar(np.arange(10), prediction, align='center')
    bar_list[ans].set_color('g')
    ax.set_xticks(np.arange(10))
    ax.set_xlim([-1, 10])
    ax.grid(True)

    plt.show()
    
    print('Predicted: {}'.format(ans))

# %% [markdown]
# ## Запуск предсказания для изображения

# %%
import random
idx = random.randint(0, test_x.shape[0])
sample = test_x[idx, ...]
test_item(sample)

print('True Answer: {}'.format(test_y[idx]))
# Out:
# Predicted: 6
# True Answer: 6
